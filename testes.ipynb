# %%
import numpy as np

from utils.image import read_video_frames


responses = read_video_frames('datasets/experimentos_taguchi/L1/L1_DA6119636_1763751213.mp4')
responses[3000]
# Out:
# array([[[25, 25, 25],
#         [25, 25, 25],
#         [25, 25, 25],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[25, 25, 25],
#         [25, 25, 25],
#         [25, 25, 25],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        [[25, 25, 25],
#         [25, 25, 25],
#         [25, 25, 25],
#         ...,
#         [48, 48, 48],
#         [48, 48, 48],
#         [48, 48, 48]],
#
#        ...,
#
#        [[37, 37, 37],
#         [37, 37, 37],
#         [37, 37, 37],
#         ...,
#         [69, 69, 69],
#         [69, 69, 69],
#         [69, 69, 69]],
#
#        [[37, 37, 37],
#         [37, 37, 37],
#         [37, 37, 37],
#         ...,
#         [69, 69, 69],
#         [69, 69, 69],
#         [69, 69, 69]],
#
#        [[37, 37, 37],
#         [37, 37, 37],
#         [37, 37, 37],
#         ...,
#         [69, 69, 69],
#         [69, 69, 69],
# ...

# %%
import matplotlib.pyplot as plt


plt.imshow(responses[3000])
